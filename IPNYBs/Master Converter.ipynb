# %%
# Run the code while in the destination folder. 
# switch between train and val as needed--------------------------here
# %cd D:\DCU\Practicum\Datasets\DeepFashion2\Deepfashion2_Dataset\train\annos\new_annotations
# Out:
# D:\DCU\Practicum\Datasets\DeepFashion2\Deepfashion2_Dataset\train\annos\new_annotations

# %%
pwd
# Out:
# 'D:\\DCU\\Practicum\\Datasets\\DeepFashion2\\Deepfashion2_Dataset\\train\\annos\\new_annotations'

# %%
#Recursively going through all the files
import glob
import pandas as pd
import os
import json
import cv2
def Convert(string): 
    li = list(string.split(",")) 
    return li

# switch between train and val as needed-----------------------------------------------------------------------here
for filepath in glob.iglob(r'D:\DCU\Practicum\Datasets\DeepFashion2\Deepfashion2_Dataset\train\annos\*.json', recursive=True):
    
    src1=filepath[-11:]#Select the last 11 characters
    sep = '.'
    filename = src1.split(sep, 1)[0]
    #print(filename)
    
    df1=pd.read_json(filepath)
    
# switch between train and val as needed-----------------------------------------------------------------------here    
    for filepath in glob.iglob(r'D:\DCU\Practicum\Datasets\DeepFashion2\Deepfashion2_Dataset\train\image\*.jpg', recursive=True):
        src2=filepath[-10:]#Select the last 10 characters(image name)
        sep = '.'
        filename1 = src2.split(sep, 1)[0]
        if(filename==filename1):
                     
            im = cv2.imread(filepath)
            h, w, c = im.shape
            #print('width:  ', w)
            #print('height: ', h)
       
    
    df1 = df1.loc[ ['category_name','segmentation'],:]
    #Filter out all the unwanted columns and keep only those columns which have the necessary clothing item segment values and the 
    #category names.
    df=df1.filter(like='item')
    n=len(df.columns) 
    if n==1:
        cat_name_1=df.iloc[0].iloc[0] #1st category
        #print("Category1:",cat_name_1)
        a1=df.iloc[1]
        
        b1=a1.iloc[0]
        
        c1=str(b1).replace("[", "")#strip('[]')
        
        d1=c1.replace("]", "")
        
        e1=Convert(d1)
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        
        x1= e1[::2] #numbers in even position
        y1= e1[1::2] #numbers in odd position
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        
        base=filename+'.jpg'
        dict1 =  {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}}]}
        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)


    elif n==2:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==3:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==4:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==5:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        cat_name_5=df.iloc[0].iloc[4]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]
        b5=a.iloc[4]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")
        c5=str(b5).replace("[", "")#strip('[]')
        d5=c5.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        e5=Convert(d5)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))
        e5=[float(i) for i in e5]
        e5=list(map(int,e5))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        x5= e5[::2]
        y5= e5[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]
        x5 = [w-1 if i>=w else i for i in x5]
        y5 = [h-1 if i>=h else i for i in y5]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x5)),
                                            'all_points_y': list(map(int, y5))},'region_attributes': {'name': cat_name_5}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==6:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        cat_name_5=df.iloc[0].iloc[4]#3nd category
        cat_name_6=df.iloc[0].iloc[5]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]
        b5=a.iloc[4]
        b6=a.iloc[5]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")
        c5=str(b5).replace("[", "")#strip('[]')
        d5=c5.replace("]", "")
        c6=str(b6).replace("[", "")#strip('[]')
        d6=c6.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        e5=Convert(d5)
        e6=Convert(d6)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))
        e5=[float(i) for i in e5]
        e5=list(map(int,e5))
        e6=[float(i) for i in e6]
        e6=list(map(int,e6))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        x5= e5[::2]
        y5= e5[1::2]
        x6= e6[::2]
        y6= e6[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]
        x5 = [w-1 if i>=w else i for i in x5]
        y5 = [h-1 if i>=h else i for i in y5]
        x6 = [w-1 if i>=w else i for i in x6]
        y6 = [h-1 if i>=h else i for i in y6]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x5)),
                                            'all_points_y': list(map(int, y5))},'region_attributes': {'name': cat_name_5}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x6)),
                                            'all_points_y': list(map(int, y6))},'region_attributes': {'name': cat_name_6}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==7:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        cat_name_5=df.iloc[0].iloc[4]#3nd category
        cat_name_6=df.iloc[0].iloc[5]#3nd category
        cat_name_7=df.iloc[0].iloc[6]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]
        b5=a.iloc[4]
        b6=a.iloc[5]
        b7=a.iloc[6]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")
        c5=str(b5).replace("[", "")#strip('[]')
        d5=c5.replace("]", "")
        c6=str(b6).replace("[", "")#strip('[]')
        d6=c6.replace("]", "")
        c7=str(b7).replace("[", "")#strip('[]')
        d7=c7.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        e5=Convert(d5)
        e6=Convert(d6)
        e7=Convert(d7)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))
        e5=[float(i) for i in e5]
        e5=list(map(int,e5))
        e6=[float(i) for i in e6]
        e6=list(map(int,e6))
        e7=[float(i) for i in e7]
        e7=list(map(int,e7))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        x5= e5[::2]
        y5= e5[1::2]
        x6= e6[::2]
        y6= e6[1::2]
        x7= e7[::2]
        y7= e7[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]
        x5 = [w-1 if i>=w else i for i in x5]
        y5 = [h-1 if i>=h else i for i in y5]
        x6 = [w-1 if i>=w else i for i in x6]
        y6 = [h-1 if i>=h else i for i in y6]
        x7 = [w-1 if i>=w else i for i in x7]
        y7 = [h-1 if i>=h else i for i in y7]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x5)),
                                            'all_points_y': list(map(int, y5))},'region_attributes': {'name': cat_name_5}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x6)),
                                            'all_points_y': list(map(int, y6))},'region_attributes': {'name': cat_name_6}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x7)),
                                            'all_points_y': list(map(int, y7))},'region_attributes': {'name': cat_name_7}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==8:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        cat_name_5=df.iloc[0].iloc[4]#3nd category
        cat_name_6=df.iloc[0].iloc[5]#3nd category
        cat_name_7=df.iloc[0].iloc[6]#3nd category
        cat_name_8=df.iloc[0].iloc[7]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]
        b5=a.iloc[4]
        b6=a.iloc[5]
        b7=a.iloc[6]
        b8=a.iloc[7]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")
        c5=str(b5).replace("[", "")#strip('[]')
        d5=c5.replace("]", "")
        c6=str(b6).replace("[", "")#strip('[]')
        d6=c6.replace("]", "")
        c7=str(b7).replace("[", "")#strip('[]')
        d7=c7.replace("]", "")
        c8=str(b8).replace("[", "")#strip('[]')
        d8=c8.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        e5=Convert(d5)
        e6=Convert(d6)
        e7=Convert(d7)
        e8=Convert(d8)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))
        e5=[float(i) for i in e5]
        e5=list(map(int,e5))
        e6=[float(i) for i in e6]
        e6=list(map(int,e6))
        e7=[float(i) for i in e7]
        e7=list(map(int,e7))
        e8=[float(i) for i in e8]
        e8=list(map(int,e8))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        x5= e5[::2]
        y5= e5[1::2]
        x6= e6[::2]
        y6= e6[1::2]
        x7= e7[::2]
        y7= e7[1::2]
        x8= e8[::2]
        y8= e8[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]
        x5 = [w-1 if i>=w else i for i in x5]
        y5 = [h-1 if i>=h else i for i in y5]
        x6 = [w-1 if i>=w else i for i in x6]
        y6 = [h-1 if i>=h else i for i in y6]
        x7 = [w-1 if i>=w else i for i in x7]
        y7 = [h-1 if i>=h else i for i in y7]
        x8 = [w-1 if i>=w else i for i in x8]
        y8 = [h-1 if i>=h else i for i in y8]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x5)),
                                            'all_points_y': list(map(int, y5))},'region_attributes': {'name': cat_name_5}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x6)),
                                            'all_points_y': list(map(int, y6))},'region_attributes': {'name': cat_name_6}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x7)),
                                            'all_points_y': list(map(int, y7))},'region_attributes': {'name': cat_name_7}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x8)),
                                            'all_points_y': list(map(int, y8))},'region_attributes': {'name': cat_name_8}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==9:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        cat_name_5=df.iloc[0].iloc[4]#3nd category
        cat_name_6=df.iloc[0].iloc[5]#3nd category
        cat_name_7=df.iloc[0].iloc[6]#3nd category
        cat_name_8=df.iloc[0].iloc[7]#3nd category
        cat_name_9=df.iloc[0].iloc[8]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]
        b5=a.iloc[4]
        b6=a.iloc[5]
        b7=a.iloc[6]
        b8=a.iloc[7]
        b9=a.iloc[8]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")
        c5=str(b5).replace("[", "")#strip('[]')
        d5=c5.replace("]", "")
        c6=str(b6).replace("[", "")#strip('[]')
        d6=c6.replace("]", "")
        c7=str(b7).replace("[", "")#strip('[]')
        d7=c7.replace("]", "")
        c8=str(b8).replace("[", "")#strip('[]')
        d8=c8.replace("]", "")
        c9=str(b9).replace("[", "")#strip('[]')
        d9=c9.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        e5=Convert(d5)
        e6=Convert(d6)
        e7=Convert(d7)
        e8=Convert(d8)
        e9=Convert(d9)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))
        e5=[float(i) for i in e5]
        e5=list(map(int,e5))
        e6=[float(i) for i in e6]
        e6=list(map(int,e6))
        e7=[float(i) for i in e7]
        e7=list(map(int,e7))
        e8=[float(i) for i in e8]
        e8=list(map(int,e8))
        e9=[float(i) for i in e9]
        e9=list(map(int,e9))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        x5= e5[::2]
        y5= e5[1::2]
        x6= e6[::2]
        y6= e6[1::2]
        x7= e7[::2]
        y7= e7[1::2]
        x8= e8[::2]
        y8= e8[1::2]
        x9= e9[::2]
        y9= e9[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]
        x5 = [w-1 if i>=w else i for i in x5]
        y5 = [h-1 if i>=h else i for i in y5]
        x6 = [w-1 if i>=w else i for i in x6]
        y6 = [h-1 if i>=h else i for i in y6]
        x7 = [w-1 if i>=w else i for i in x7]
        y7 = [h-1 if i>=h else i for i in y7]
        x8 = [w-1 if i>=w else i for i in x8]
        y8 = [h-1 if i>=h else i for i in y8]
        x9 = [w-1 if i>=w else i for i in x9]
        y9 = [h-1 if i>=h else i for i in y9]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x5)),
                                            'all_points_y': list(map(int, y5))},'region_attributes': {'name': cat_name_5}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x6)),
                                            'all_points_y': list(map(int, y6))},'region_attributes': {'name': cat_name_6}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x7)),
                                            'all_points_y': list(map(int, y7))},'region_attributes': {'name': cat_name_7}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x8)),
                                            'all_points_y': list(map(int, y8))},'region_attributes': {'name': cat_name_8}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x9)),
                                            'all_points_y': list(map(int, y9))},'region_attributes': {'name': cat_name_9}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)
            
    elif n==10:
        cat_name_1=df.iloc[0].iloc[0]#1st category
        cat_name_2=df.iloc[0].iloc[1]#2nd category
        cat_name_3=df.iloc[0].iloc[2]#3nd category
        cat_name_4=df.iloc[0].iloc[3]#3nd category
        cat_name_5=df.iloc[0].iloc[4]#3nd category
        cat_name_6=df.iloc[0].iloc[5]#3nd category
        cat_name_7=df.iloc[0].iloc[6]#3nd category
        cat_name_8=df.iloc[0].iloc[7]#3nd category
        cat_name_9=df.iloc[0].iloc[8]#3nd category
        cat_name_10=df.iloc[0].iloc[9]#3nd category
        #print("Category1:",cat_name_1,"\nCategory2:",cat_name_2)
        a=df.iloc[1]

        b1=a.iloc[0]
        b2=a.iloc[1]
        b3=a.iloc[2]
        b4=a.iloc[3]
        b5=a.iloc[4]
        b6=a.iloc[5]
        b7=a.iloc[6]
        b8=a.iloc[7]
        b9=a.iloc[8]
        b10=a.iloc[9]

        c1=str(b1).replace("[", "")#strip('[]')
        d1=c1.replace("]", "")
        c2=str(b2).replace("[", "")#strip('[]')
        d2=c2.replace("]", "")
        c3=str(b3).replace("[", "")#strip('[]')
        d3=c3.replace("]", "")
        c4=str(b4).replace("[", "")#strip('[]')
        d4=c4.replace("]", "")
        c5=str(b5).replace("[", "")#strip('[]')
        d5=c5.replace("]", "")
        c6=str(b6).replace("[", "")#strip('[]')
        d6=c6.replace("]", "")
        c7=str(b7).replace("[", "")#strip('[]')
        d7=c7.replace("]", "")
        c8=str(b8).replace("[", "")#strip('[]')
        d8=c8.replace("]", "")
        c9=str(b9).replace("[", "")#strip('[]')
        d9=c9.replace("]", "")
        c10=str(b10).replace("[", "")#strip('[]')
        d10=c10.replace("]", "")

        e1=Convert(d1)
        e2=Convert(d2)
        e3=Convert(d3)
        e4=Convert(d4)
        e5=Convert(d5)
        e6=Convert(d6)
        e7=Convert(d7)
        e8=Convert(d8)
        e9=Convert(d9)
        e10=Convert(d10)
        
        e1=[float(i) for i in e1]
        e1=list(map(int,e1))
        e2=[float(i) for i in e2]
        e2=list(map(int,e2))
        e3=[float(i) for i in e3]
        e3=list(map(int,e3))
        e4=[float(i) for i in e4]
        e4=list(map(int,e4))
        e5=[float(i) for i in e5]
        e5=list(map(int,e5))
        e6=[float(i) for i in e6]
        e6=list(map(int,e6))
        e7=[float(i) for i in e7]
        e7=list(map(int,e7))
        e8=[float(i) for i in e8]
        e8=list(map(int,e8))
        e9=[float(i) for i in e9]
        e9=list(map(int,e9))
        e10=[float(i) for i in e10]
        e10=list(map(int,e10))

        x1= e1[::2]
        y1= e1[1::2] 
        x2= e2[::2]
        y2= e2[1::2]
        x3= e3[::2]
        y3= e3[1::2]
        x4= e4[::2]
        y4= e4[1::2]
        x5= e5[::2]
        y5= e5[1::2]
        x6= e6[::2]
        y6= e6[1::2]
        x7= e7[::2]
        y7= e7[1::2]
        x8= e8[::2]
        y8= e8[1::2]
        x9= e9[::2]
        y9= e9[1::2]
        x10= e10[::2]
        y10= e10[1::2]
        
        x1 = [w-1 if i>=w else i for i in x1]
        y1 = [h-1 if i>=h else i for i in y1]
        x2 = [w-1 if i>=w else i for i in x2]
        y2 = [h-1 if i>=h else i for i in y2]
        x3 = [w-1 if i>=w else i for i in x3]
        y3 = [h-1 if i>=h else i for i in y3]
        x4 = [w-1 if i>=w else i for i in x4]
        y4 = [h-1 if i>=h else i for i in y4]
        x5 = [w-1 if i>=w else i for i in x5]
        y5 = [h-1 if i>=h else i for i in y5]
        x6 = [w-1 if i>=w else i for i in x6]
        y6 = [h-1 if i>=h else i for i in y6]
        x7 = [w-1 if i>=w else i for i in x7]
        y7 = [h-1 if i>=h else i for i in y7]
        x8 = [w-1 if i>=w else i for i in x8]
        y8 = [h-1 if i>=h else i for i in y8]
        x9 = [w-1 if i>=w else i for i in x9]
        y9 = [h-1 if i>=h else i for i in y9]
        x10 = [w-1 if i>=w else i for i in x10]
        y10 = [h-1 if i>=h else i for i in y10]

        base=filename+'.jpg'
        dict1 = {'filename': base,'regions': [{'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x1)),
                                             'all_points_y': list(map(int, y1))},'region_attributes': {'name': cat_name_1}},
                                                
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x2)),
                                             'all_points_y': list(map(int, y2))},'region_attributes': {'name': cat_name_2}},
                                             
                                              {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x3)),
                                            'all_points_y': list(map(int, y3))},'region_attributes': {'name': cat_name_3}},
                                              
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x4)),
                                            'all_points_y': list(map(int, y4))},'region_attributes': {'name': cat_name_4}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x5)),
                                            'all_points_y': list(map(int, y5))},'region_attributes': {'name': cat_name_5}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x6)),
                                            'all_points_y': list(map(int, y6))},'region_attributes': {'name': cat_name_6}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x7)),
                                            'all_points_y': list(map(int, y7))},'region_attributes': {'name': cat_name_7}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x8)),
                                            'all_points_y': list(map(int, y8))},'region_attributes': {'name': cat_name_8}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x9)),
                                            'all_points_y': list(map(int, y9))},'region_attributes': {'name': cat_name_9}},
                                             
                                             {'shape_attributes': {'name': 'polygon','all_points_x': list(map(int, x10)),
                                            'all_points_y': list(map(int, y10))},'region_attributes': {'name': cat_name_10}}]}

        with open(filename+'_new.json', 'w') as fp:
            json.dump(dict1, fp)

    else:
        print("There are",n,"categories. Include more.");
        break;
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d00074213ca5> in <module>
#      26         if(filename==filename1):
#      27
# ---> 28             im = cv2.imread(filepath)
#      29             h, w, c = im.shape
#      30             #print('width:  ', w)
#
# KeyboardInterrupt:

# %%
# Run the code while in the destination folder. 
# switch between train and val as needed--------------------------here
# %cd D:\DCU\Practicum\Datasets\DeepFashion2\Mask RCNN\Clothes\Dataset Splits\new_annotations_val
# Out:
# D:\DCU\Practicum\Datasets\DeepFashion2\Mask RCNN\Clothes\Dataset Splits\new_annotations_val

# %%
pwd
# Out:
# 'D:\\DCU\\Practicum\\Datasets\\DeepFashion2\\Mask RCNN\\Clothes\\Dataset Splits\\new_annotations_val'

# %%
import glob

read_files = glob.glob("*.json")
with open("via_region_data.json", "w") as outfile:
    outfile.write('[{}]'.format(','.join([open(f, "r").read() for f in read_files])))
